# %%
total_revenue   | total_orders | average_ticket (AOV)
----------------|---------------|-------------
R$ 15.419.773,75| 96478         | R$ 159,83

# %%
orders_delivered | orders_canceled | orders_others
-----------------|-----------------|-------------
96478            | 625             | 2338

# %%
From the total of 99441 registered orders, 97.02% were delivered, generating a revenue of R$ 15419773.75 with a AOV of R$ 159.83. The 625 canceled orders represent 0.63% of the transaction volume.
# Out:
#   Cell In[1], line 1
#     From the total of 99441 registered orders, 97.02% were delivered, generating a revenue of R$ 15419773.75 with a AOV of R$ 159.83.
#          ^
# SyntaxError: invalid syntax
